# %% [markdown]
# # >>>> Credit_Card_Approval_Prediction <<<<

# %% [markdown]
# **Project overview**

# %% [markdown]
# A bank's credit card department is one of the top adopters of data science. A top focus for the bank has always been acquiring new credit card customers. Giving out credit cards without doing proper research or evaluating applicants' creditworthiness is quite risky. The credit card department has been using a data-driven system for credit assessment called Credit Scoring for many years, and the model is known as an application scorecard. A credit card application's cutoff value is determined using the application scorecard, which also aids in estimating the applicant's level of risk. This decision is made based on strategic priority at a given time. Customers must fill out a form, either physically or online, to apply for a credit card. The application data is used to evaluate the applicant's creditworthiness. The decision is made using the application data in addition to the Credit Bureau Score, such as the FICO Score in the US or the CIBIL Score in India, and other internal information on the applicants. Additionally, the banks are rapidly taking a lot of outside data into account to enhance the caliber of credit judgements.

# %% [markdown]
# **Project objective**

# %% [markdown]
# The main objective of this assignment is to minimize the risk and maximize the profit of the bank. Bank has to make a decision based on the applicant's profile to minimize the loss from the bank's perspective. Bank considers the applicant's over their nature of work, income range and family orientaion details to take any decision to approve or reject a credit card application. The customer Credit card data contains many features and a classification approach to identify the credit worthiness of an applicant. In this project we are utilizing the exploratory data analysis (EDA) as a data exploration technique to acquire knowledge, discover new relations, apply new methodologies and unravel patterns in data. It is important to apply the necessary rationale behind each step to address the main objective of the study. So, The primary objective of this project is to develop a machine learning model for Credit Card Approval Prediction.

# %% [markdown]
#  #                          Section 1

# %% [markdown]
# **1. Why is your proposal important in today’s world? How predicting a good client is worthy for a bank?**

# %% [markdown]
# In today's world, the proposal holds significant importance as it empowers financial institutions to make more informed lending decisions. Banks and financial institutions have vested interest in identifying and serving clients who are likely to be creditworthy and financially stable, here are why predictig good clients are worthy for banks:
#
# **Risk Mitigation:--->** Banks face significant financial risks when extending credit to individuals who may default on their payments. Predictive models help identify clients who are more likely to meet their financial obligations, reducing the risk of bad loans and potential financial losses.
#
# **Improved Profitability:--->** By accurately identifying creditworthy clients, banks can increase their profitability. These clients are more likely to make on-time payments, incurring fewer late fees and lower interest rates, which can positively affect the bank's revenue.
#
# **Enhanced Customer Experience:--->** Predictive models not only help in identifying good clients but also contribute to a better customer experience. When deserving clients are approved more quickly, it leads to customer satisfaction and loyalty.
#
# **Efficient Resource Allocation:--->** The bank can allocate its resources more efficiently by concentrating on creditworthy clients. This reduces the cost of chasing bad debts and streamlines the loan approval process, making it more cost-effective.
#
# **Compliance and Regulatory Requirements:--->** Many regulatory authorities require banks to demonstrate responsible lending practices. Predictive models ensure that banks adhere to these regulations by ensuring loans are granted to clients who can afford them.
#
# **Competitive Advantage:--->** In a competitive financial market, banks that can accurately assess creditworthiness can attract better clients and gain a competitive advantage over others. This leads to increased market share and business growth.
#
# **Data-Driven Decision-Making:--->** The modern world relies heavily on data-driven decision-making. Credit approval prediction leverages data science and analytics to make informed choices, contributing to the growing trend of data-driven banking.
#
#
# --->Predicting good clients is essential for a bank to reduce risks, increase profitability, improve the customer experience, and stay compliant with regulatory requirements. It also provides a competitive edge and aligns with the data-centric approach prevalent in today's financial industry.

# %% [markdown]
# **2. How is it going to impact the banking sector?**

# %% [markdown]
# The proposal's implementation is poised to have a profound impact on the banking sector. By enhancing the ability to predict creditworthiness, banks can significantly reduce the risk associated with lending. This, in turn, can lead to a more stable financial environment, with fewer defaults and bad loans. Moreover, it can streamline the lending process, making it more efficient and customer-centric, thereby improving the overall customer experience.
#
# Furthermore, as regulatory authorities increasingly emphasize responsible lending practices, implementing such predictive models becomes essential for compliance. Banks that effectively employ these tools will not only meet regulatory requirements but also gain a competitive edge in the industry, attracting more desirable clients and ultimately increasing market share.
#
# Ultimately, the proposal's impact is multifaceted, spanning risk reduction, improved efficiency, regulatory compliance, and competitiveness, making it a transformative force in the modern banking sector.

# %% [markdown]
# **3. If any, what is the gap in the knowledge or how your proposed method can be helpful if required in future for any bank in India.**

# %% [markdown]
# The proposed creditworthiness prediction method can indeed be beneficial for banks in India, but there are potential gaps in knowledge and considerations for its future implementation. One major challenge is the availability and quality of data. Indian banks often deal with a diverse customer base, and data quality and coverage can vary significantly. Ensuring the collection and maintenance of accurate and comprehensive data is crucial for the success of any predictive model.
#
# Additionally, the legal and regulatory landscape in India is subject to change. Banking regulations, privacy laws, and data protection requirements can evolve, affecting the way customer data can be utilized. Continuous monitoring and adaptation to these legal changes will be necessary to ensure compliance.
#
# Furthermore, the method's success will depend on continuous model retraining to adapt to changing economic conditions and customer behaviors. The dynamic nature of the Indian economy necessitates constant updates to maintain prediction accuracy.
#
# In conclusion, while the proposed method offers significant benefits to banks in India, addressing data quality, staying compliant with evolving regulations, and maintaining model accuracy over time are key considerations for its successful implementation in the future.

# %% [markdown]
# # Section 2:-  Initial Hypothesis (or hypotheses)

# %% [markdown]
# The initial hypotheses would revolve around identifying patterns and important features that impact a machine learning (ML) model's ability to predict creditworthiness.
#
# **Hypothesis 1: Credit Score Correlation --->** there is a strong positive correlation between credit scores and credit card approval. Applicants with higher credit scores are more likely to be approved.
#
# **Hypothesis 2: Income Influence --->** It seems that a higher income level is positively associated with credit card approval. Those with greater income are more likely to have the means to meet their financial obligations.
#
# **Hypothesis 3: Employment Status --->**  Employed applicants have a higher likelihood of approval compared to unemployed or self-employed applicants due to a stable income source.
#
# **Hypothesis 4: Debt-to-Income Ratio --->** A lower debt-to-income ratio will positively influence approval, as it indicates a lower financial burden for the applicant.
#
# **Hypothesis 5: Age Factor --->** Age may play a role in approval, with older applicants being favored as they might be perceived as more financially responsible.
#
# **Hypothesis 6: Address Stability --->** Individuals with a longer history at their current address may have a higher likelihood of approval, reflecting stability.
#
# These initial hypotheses serve as starting points for the data analysis, helping to identify the significant factors that impact credit card approval and guiding the feature selection and engineering process for the ML model.

# %% [markdown]
# # Import Liberaries for Data Exploration and Preprocessing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')
from scipy import stats
from scipy.stats import boxcox
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Import DataSet

# %%
credit_card_data = pd.read_csv("Credit_card.csv")
crdit_label_data = pd.read_csv("Credit_card_label.csv")
credit_card_data
# Out:
#        Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0     5008827      M         Y             Y         0       180000.0
# 1     5009744      F         Y             N         0       315000.0
# 2     5009746      F         Y             N         0       315000.0
# 3     5009749      F         Y             N         0            NaN
# 4     5009752      F         Y             N         0       315000.0
# ...       ...    ...       ...           ...       ...            ...
# 1543  5028645      F         N             Y         0            NaN
# 1544  5023655      F         N             N         0       225000.0
# 1545  5115992      M         Y             Y         2       180000.0
# 1546  5118219      M         Y             N         0       270000.0
# 1547  5053790      F         Y             Y         0       225000.0
#
#                Type_Income                      EDUCATION  \
# 0                Pensioner               Higher education
# ...

# %%
crdit_label_data
# Out:
#        Ind_ID  label
# 0     5008827      1
# 1     5009744      1
# 2     5009746      1
# 3     5009749      1
# 4     5009752      1
# ...       ...    ...
# 1543  5028645      0
# 1544  5023655      0
# 1545  5115992      0
# 1546  5118219      0
# 1547  5053790      0
#
# [1548 rows x 2 columns]

# %%
credit_card_data.info()
print("***************************************************************")
crdit_label_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1548 entries, 0 to 1547
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Ind_ID           1548 non-null   int64
#  1   GENDER           1541 non-null   object
#  2   Car_Owner        1548 non-null   object
#  3   Propert_Owner    1548 non-null   object
#  4   CHILDREN         1548 non-null   int64
#  5   Annual_income    1525 non-null   float64
#  6   Type_Income      1548 non-null   object
#  7   EDUCATION        1548 non-null   object
#  8   Marital_status   1548 non-null   object
#  9   Housing_type     1548 non-null   object
#  10  Birthday_count   1526 non-null   float64
#  11  Employed_days    1548 non-null   int64
#  12  Mobile_phone     1548 non-null   int64
#  13  Work_Phone       1548 non-null   int64
#  14  Phone            1548 non-null   int64
#  15  EMAIL_ID         1548 non-null   int64
#  16  Type_Occupation  1060 non-null   object
# ...

# %% [markdown]
# # DataSet Merge

# %%
#as both the datasets are havng same records (number of rows) and part of one dataset we are merging them

data = pd.merge(credit_card_data, crdit_label_data, on='Ind_ID')
df = data.copy()
df
# Out:
#        Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0     5008827      M         Y             Y         0       180000.0
# 1     5009744      F         Y             N         0       315000.0
# 2     5009746      F         Y             N         0       315000.0
# 3     5009749      F         Y             N         0            NaN
# 4     5009752      F         Y             N         0       315000.0
# ...       ...    ...       ...           ...       ...            ...
# 1543  5028645      F         N             Y         0            NaN
# 1544  5023655      F         N             N         0       225000.0
# 1545  5115992      M         Y             Y         2       180000.0
# 1546  5118219      M         Y             N         0       270000.0
# 1547  5053790      F         Y             Y         0       225000.0
#
#                Type_Income                      EDUCATION  \
# 0                Pensioner               Higher education
# ...

# %% [markdown]
# # >>>Basic Data Exploration & EDA<<<

# %%
df.shape
# Out:
# (1548, 19)

# %%
df.columns
# Out:
# Index(['Ind_ID', 'GENDER', 'Car_Owner', 'Propert_Owner', 'CHILDREN',
#        'Annual_income', 'Type_Income', 'EDUCATION', 'Marital_status',
#        'Housing_type', 'Birthday_count', 'Employed_days', 'Mobile_phone',
#        'Work_Phone', 'Phone', 'EMAIL_ID', 'Type_Occupation', 'Family_Members',
#        'label'],
#       dtype='object')

# %%
(df["label"].value_counts()/df.shape[0])*100
# Out:
# 0    88.69509
# 1    11.30491
# Name: label, dtype: float64

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Ind_ID, GENDER, Car_Owner, Propert_Owner, CHILDREN, Annual_income, Type_Income, EDUCATION, Marital_status, Housing_type, Birthday_count, Employed_days, Mobile_phone, Work_Phone, Phone, EMAIL_ID, Type_Occupation, Family_Members, label]
# Index: []

# %%
df.isnull().sum().sort_values(ascending = False)
# Out:
# Type_Occupation    488
# Annual_income       23
# Birthday_count      22
# GENDER               7
# Ind_ID               0
# Employed_days        0
# Family_Members       0
# EMAIL_ID             0
# Phone                0
# Work_Phone           0
# Mobile_phone         0
# Housing_type         0
# Marital_status       0
# EDUCATION            0
# Type_Income          0
# CHILDREN             0
# Propert_Owner        0
# Car_Owner            0
# label                0
# dtype: int64

# %%
(df.isna().sum()/len(df)*100).sort_values(ascending = False)
# Out:
# Type_Occupation    31.524548
# Annual_income       1.485788
# Birthday_count      1.421189
# GENDER              0.452196
# Ind_ID              0.000000
# Employed_days       0.000000
# Family_Members      0.000000
# EMAIL_ID            0.000000
# Phone               0.000000
# Work_Phone          0.000000
# Mobile_phone        0.000000
# Housing_type        0.000000
# Marital_status      0.000000
# EDUCATION           0.000000
# Type_Income         0.000000
# CHILDREN            0.000000
# Propert_Owner       0.000000
# Car_Owner           0.000000
# label               0.000000
# dtype: float64

# %% [markdown]
# # EDA >> Exploratory Data Analysis

# %%
plt.figure(figsize= (8,6))
sns.countplot(x=df[df["Type_Occupation"].isna()]["Type_Income"])
plt.title("Don't have type occupation customers INCOME TYPE")
# Out:
# Text(0.5, 1.0, "Don't have type occupation customers INCOME TYPE")

# %% [markdown]
# **Customers having null occupation types seems to be from Pensioners category**

# %%
df.loc[df["Type_Income"] == "Pensioner", "Type_Occupation"] = "Pensioner"

# %%
df["Type_Income"].value_counts()
# Out:
# Working                 798
# Commercial associate    365
# Pensioner               269
# State servant           116
# Name: Type_Income, dtype: int64

# %%
(df.isna().sum()/len(df)*100).sort_values(ascending = False)
# Out:
# Type_Occupation    14.470284
# Annual_income       1.485788
# Birthday_count      1.421189
# GENDER              0.452196
# Ind_ID              0.000000
# Employed_days       0.000000
# Family_Members      0.000000
# EMAIL_ID            0.000000
# Phone               0.000000
# Work_Phone          0.000000
# Mobile_phone        0.000000
# Housing_type        0.000000
# Marital_status      0.000000
# EDUCATION           0.000000
# Type_Income         0.000000
# CHILDREN            0.000000
# Propert_Owner       0.000000
# Car_Owner           0.000000
# label               0.000000
# dtype: float64

# %%
plt.figure(figsize= (8,6))
sns.countplot(x=df[df["Type_Occupation"].isna()]["Type_Income"])
plt.title("Don't have type occupation customers INCOME TYPE")
# Out:
# Text(0.5, 1.0, "Don't have type occupation customers INCOME TYPE")

# %% [markdown]
# **Remaining customers having null valuse seems to belongs from some "Working" category**

# %%
df.loc[df["Type_Income"] == "Working", "Type_Occupation"] = "Working"

# %%
df["Type_Income"].value_counts()
# Out:
# Working                 798
# Commercial associate    365
# Pensioner               269
# State servant           116
# Name: Type_Income, dtype: int64

# %%
(df.isna().sum()/len(df)*100).sort_values(ascending = False)
# Out:
# Type_Occupation    6.136951
# Annual_income      1.485788
# Birthday_count     1.421189
# GENDER             0.452196
# Ind_ID             0.000000
# Employed_days      0.000000
# Family_Members     0.000000
# EMAIL_ID           0.000000
# Phone              0.000000
# Work_Phone         0.000000
# Mobile_phone       0.000000
# Housing_type       0.000000
# Marital_status     0.000000
# EDUCATION          0.000000
# Type_Income        0.000000
# CHILDREN           0.000000
# Propert_Owner      0.000000
# Car_Owner          0.000000
# label              0.000000
# dtype: float64

# %% [markdown]
# **6% data is still available in dataset**

# %%
plt.figure(figsize= (8,6))
sns.countplot(x=df[df["Type_Occupation"].isna()]["Type_Income"])
plt.title("Don't have type occupation customers INCOME TYPE")
# Out:
# Text(0.5, 1.0, "Don't have type occupation customers INCOME TYPE")

# %%
df.loc[df["Type_Income"] == "Commercial associate", "Type_Occupation"] = "Commercial associate"

# %%
df["Type_Income"].value_counts()
# Out:
# Working                 798
# Commercial associate    365
# Pensioner               269
# State servant           116
# Name: Type_Income, dtype: int64

# %%
(df.isna().sum()/len(df)*100).sort_values(ascending = False)
# Out:
# Annual_income      1.485788
# Birthday_count     1.421189
# Type_Occupation    1.162791
# GENDER             0.452196
# Ind_ID             0.000000
# Employed_days      0.000000
# Family_Members     0.000000
# EMAIL_ID           0.000000
# Phone              0.000000
# Work_Phone         0.000000
# Mobile_phone       0.000000
# Housing_type       0.000000
# Marital_status     0.000000
# EDUCATION          0.000000
# Type_Income        0.000000
# CHILDREN           0.000000
# Propert_Owner      0.000000
# Car_Owner          0.000000
# label              0.000000
# dtype: float64

# %%
df.isna().sum()/len(df)*100
# Out:
# Ind_ID             0.000000
# GENDER             0.452196
# Car_Owner          0.000000
# Propert_Owner      0.000000
# CHILDREN           0.000000
# Annual_income      1.485788
# Type_Income        0.000000
# EDUCATION          0.000000
# Marital_status     0.000000
# Housing_type       0.000000
# Birthday_count     1.421189
# Employed_days      0.000000
# Mobile_phone       0.000000
# Work_Phone         0.000000
# Phone              0.000000
# EMAIL_ID           0.000000
# Type_Occupation    1.162791
# Family_Members     0.000000
# label              0.000000
# dtype: float64

# %% [markdown]
# **As the less han 2% null values are there in dataset we can simply remove those rows**

# %%
df = df.dropna(axis=0)

# %%
df.isna().sum()/len(df)*100
# Out:
# Ind_ID             0.0
# GENDER             0.0
# Car_Owner          0.0
# Propert_Owner      0.0
# CHILDREN           0.0
# Annual_income      0.0
# Type_Income        0.0
# EDUCATION          0.0
# Marital_status     0.0
# Housing_type       0.0
# Birthday_count     0.0
# Employed_days      0.0
# Mobile_phone       0.0
# Work_Phone         0.0
# Phone              0.0
# EMAIL_ID           0.0
# Type_Occupation    0.0
# Family_Members     0.0
# label              0.0
# dtype: float64

# %% [markdown]
# # Save Clean data to CSV file for analysis in MYSQL

# %%
df.to_csv("Credit_card_cleaned_data.csv")

# %%
#dropped irrelevant feature
df.drop("Ind_ID", axis=1, inplace=True)

# %%
df.reset_index(drop=True)
# Out:
#      GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0         M         Y             Y         0       180000.0
# 1         F         Y             N         0       315000.0
# 2         F         Y             N         0       315000.0
# 3         F         Y             N         0       315000.0
# 4         F         N             N         0       180000.0
# ...     ...       ...           ...       ...            ...
# 1473      M         Y             N         1       360000.0
# 1474      F         N             N         0       225000.0
# 1475      M         Y             Y         2       180000.0
# 1476      M         Y             N         0       270000.0
# 1477      F         Y             Y         0       225000.0
#
#                Type_Income                      EDUCATION  \
# 0                Pensioner               Higher education
# 1     Commercial associate               Higher education
# ...

# %% [markdown]
# splitting the data into independent variable and dependent varible.

# %%
X = df.drop("label", axis=1)  # independent variables
y = df["label"] #dependent variable / target variable

# %%
X["Age"] = (-X["Birthday_count"]/365).astype(int)

# %%
X = X.drop("Birthday_count", axis=1)

# %%
X.head(5)
# Out:
#   GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0      M         Y             Y         0       180000.0
# 1      F         Y             N         0       315000.0
# 4      F         Y             N         0       315000.0
# 6      F         Y             N         0       315000.0
# 7      F         N             N         0       180000.0
#
#             Type_Income                      EDUCATION Marital_status  \
# 0             Pensioner               Higher education        Married
# 1  Commercial associate               Higher education        Married
# 4  Commercial associate               Higher education        Married
# 6  Commercial associate               Higher education        Married
# 7             Pensioner  Secondary / secondary special        Married
#
#         Housing_type  Employed_days  Mobile_phone  Work_Phone  Phone  \
# 0  House / apartment         365243             1           0      0
# ...

# %%
#converting employed days into employment years


def emp_years(x):
    if x>=0:
        return 0
    else:
        return float(round((-x/365),2))
X["Employement_Years"] = X["Employed_days"].apply(emp_years)
X = X.drop("Employed_days", axis=1)



X.head()
# Out:
#   GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0      M         Y             Y         0       180000.0
# 1      F         Y             N         0       315000.0
# 4      F         Y             N         0       315000.0
# 6      F         Y             N         0       315000.0
# 7      F         N             N         0       180000.0
#
#             Type_Income                      EDUCATION Marital_status  \
# 0             Pensioner               Higher education        Married
# 1  Commercial associate               Higher education        Married
# 4  Commercial associate               Higher education        Married
# 6  Commercial associate               Higher education        Married
# 7             Pensioner  Secondary / secondary special        Married
#
#         Housing_type  Mobile_phone  Work_Phone  Phone  EMAIL_ID  \
# 0  House / apartment             1           0      0         0
# ...

# %%
X.describe()
# Out:
#           CHILDREN  Annual_income  Mobile_phone   Work_Phone        Phone  \
# count  1478.000000   1.478000e+03        1478.0  1478.000000  1478.000000
# mean      0.415426   1.909854e+05           1.0     0.205007     0.305819
# std       0.781007   1.134259e+05           0.0     0.403843     0.460909
# min       0.000000   3.375000e+04           1.0     0.000000     0.000000
# 25%       0.000000   1.215000e+05           1.0     0.000000     0.000000
# 50%       0.000000   1.665000e+05           1.0     0.000000     0.000000
# 75%       1.000000   2.250000e+05           1.0     0.000000     1.000000
# max      14.000000   1.575000e+06           1.0     1.000000     1.000000
#
#           EMAIL_ID  Family_Members          Age  Employement_Years
# count  1478.000000     1478.000000  1478.000000        1478.000000
# mean      0.092693        2.164411    43.483085           6.078877
# std       0.290100        0.951444    11.558953           6.571361
# ...

# %%
#Grouping Categorical features with help of datatype "Objet" and numerical with dtype "Int and Float"

cat = []
num = []
for i in list(X.columns):
    if X[i].dtype == "object":
        cat.append(i)
    else:
        num.append(i)

# %%
cat
# Out:
# ['GENDER',
#  'Car_Owner',
#  'Propert_Owner',
#  'Type_Income',
#  'EDUCATION',
#  'Marital_status',
#  'Housing_type',
#  'Type_Occupation']

# %%
num
# Out:
# ['CHILDREN',
#  'Annual_income',
#  'Mobile_phone',
#  'Work_Phone',
#  'Phone',
#  'EMAIL_ID',
#  'Family_Members',
#  'Age',
#  'Employement_Years']

# %%
#histplot of all numerical features to check distribution and their skewness

plt.figure(figsize=(20,30))
for i in enumerate(X[num]):
    plt.subplot(3,3, i[0]+1)
    sns.set (rc = {'figure.figsize' : (10,5)})
    sns.histplot(data = X, x = i[1], kde=True)
    skewness = X[i[1]].skew()
    plt.title("{}'s distribution with skewness = {}". format(i[1], skewness))

# %% [markdown]
# **Annual income and Emloyement years are slightly Right/+ve skewed**

# %%
X["Employement_Years"] = np.sqrt(X["Employement_Years"])
X["Employement_Years"].skew()
# Out:
# 0.2512261854156458

# %%
X["Annual_income"] = np.log(X["Annual_income"])
X["Annual_income"].skew()
# Out:
# 0.20194187448088688

# %%
#detecting outliers in numerical features 

plt.figure(figsize=(20,24))
for i in enumerate(X[num]):
    plt.subplot(3,3, i[0]+1)
    sns.set (rc = {'figure.figsize' : (10,5)})
    sns.boxplot(data = X, x = i[1])

# %%
X["Annual_income"].describe()
# Out:
# count    1478.000000
# mean       12.034958
# std         0.487696
# min        10.426736
# 25%        11.707670
# 50%        12.022751
# 75%        12.323856
# max        14.269766
# Name: Annual_income, dtype: float64

# %%
Q1 = X["Annual_income"].quantile(0.25)
Q2 = X["Annual_income"].quantile(0.50)
Q3 = X["Annual_income"].quantile(0.75)

iqr = Q3-Q1

u_l = Q3+(1.5*iqr)
l_l = Q1-(1.5*iqr)

# %%
X["Annual_income"] = X["Annual_income"].clip(lower=l_l, upper= u_l)

# %%
sns.boxplot(X["Annual_income"])
plt.show()

# %%
plt.figure(figsize=(20,15))
for i in enumerate(X[cat]):
    plt.subplot(3,3, i[0]+1)
    sns.set (rc = {'figure.figsize' : (25,5)})
    plt.xticks(rotation = 55)
    sns.histplot(data = X, x = i[1])
    plt.show()

# %%
sns.pairplot(X, hue='GENDER')
plt.show()

# %%
#checking correlation between features
X.corr()
# Out:
#                    CHILDREN  Annual_income  Mobile_phone  Work_Phone  \
# CHILDREN           1.000000       0.064877           NaN    0.028176
# Annual_income      0.064877       1.000000           NaN   -0.069339
# Mobile_phone            NaN            NaN           NaN         NaN
# Work_Phone         0.028176      -0.069339           NaN    1.000000
# Phone             -0.014619      -0.017581           NaN    0.354054
# EMAIL_ID           0.024165       0.133820           NaN   -0.006276
# Family_Members     0.891134       0.048451           NaN    0.065520
# Age               -0.286611      -0.122558           NaN   -0.178454
# Employement_Years  0.133785       0.160254           NaN    0.166500
#
#                       Phone  EMAIL_ID  Family_Members       Age  \
# CHILDREN          -0.014619  0.024165        0.891134 -0.286611
# Annual_income     -0.017581  0.133820        0.048451 -0.122558
# Mobile_phone            NaN       NaN             NaN       NaN
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(X.corr(), annot=True, cmap='coolwarm', fmt='.2f', linewidth=0.5)
plt.title("Correlation Plot")

plt.show()

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1478 entries, 0 to 1547
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GENDER             1478 non-null   object
#  1   Car_Owner          1478 non-null   object
#  2   Propert_Owner      1478 non-null   object
#  3   CHILDREN           1478 non-null   int64
#  4   Annual_income      1478 non-null   float64
#  5   Type_Income        1478 non-null   object
#  6   EDUCATION          1478 non-null   object
#  7   Marital_status     1478 non-null   object
#  8   Housing_type       1478 non-null   object
#  9   Mobile_phone       1478 non-null   int64
#  10  Work_Phone         1478 non-null   int64
#  11  Phone              1478 non-null   int64
#  12  EMAIL_ID           1478 non-null   int64
#  13  Type_Occupation    1478 non-null   object
#  14  Family_Members     1478 non-null   int64
#  15  Age                1478 non-null   int32
# ...

# %%
X["GENDER"].value_counts()
# Out:
# F    936
# M    542
# Name: GENDER, dtype: int64

# %%
X["Car_Owner"].value_counts()
# Out:
# N    887
# Y    591
# Name: Car_Owner, dtype: int64

# %%
X["Propert_Owner"].value_counts()
# Out:
# Y    966
# N    512
# Name: Propert_Owner, dtype: int64

# %%
X["Type_Income"].value_counts()
# Out:
# Working                 769
# Commercial associate    353
# Pensioner               259
# State servant            97
# Name: Type_Income, dtype: int64

# %%
X["Marital_status"].value_counts()
# Out:
# Married                 998
# Single / not married    216
# Civil marriage          100
# Separated                90
# Widow                    74
# Name: Marital_status, dtype: int64

# %%
X["Housing_type"].value_counts()
# Out:
# House / apartment      1315
# With parents             78
# Municipal apartment      51
# Rented apartment         20
# Office apartment          9
# Co-op apartment           5
# Name: Housing_type, dtype: int64

# %%
X["Type_Occupation"].value_counts()
# Out:
# Working                  769
# Commercial associate     353
# Pensioner                259
# Core staff                35
# Medicine staff            17
# Managers                  14
# Laborers                   9
# High skill tech staff      8
# Accountants                5
# Drivers                    4
# Secretaries                2
# Private service staff      2
# Cooking staff              1
# Name: Type_Occupation, dtype: int64

# %%
X["EDUCATION"].value_counts()
# Out:
# Secondary / secondary special    991
# Higher education                 399
# Incomplete higher                 65
# Lower secondary                   21
# Academic degree                    2
# Name: EDUCATION, dtype: int64

# %% [markdown]
# # Feature Encoding

# %% [markdown]
# **Ordinal encoding as "EDUCATION" feture is having order categorical data**

# %%
X["EDUCATION"] = X["EDUCATION"].map({"Academic degree" : 4, "Secondary / secondary special" : 3, "Lower secondary" : 2, "Higher education" : 1, "Incomplete higher" : 0})

# %%
X["EDUCATION"].unique()
# Out:
# array([1, 3, 2, 0, 4], dtype=int64)

# %%
cat_dummy = pd.get_dummies(data=X[["GENDER", 
                       "Car_Owner", 
                       "Propert_Owner", 
                       "Type_Income", 
                       "Marital_status", 
                       "Housing_type", 
                       "Type_Occupation"]], drop_first=True)

# %%
cat_dummy
# Out:
#       GENDER_M  Car_Owner_Y  Propert_Owner_Y  Type_Income_Pensioner  \
# 0            1            1                1                      1
# 1            0            1                0                      0
# 4            0            1                0                      0
# 6            0            1                0                      0
# 7            0            0                0                      1
# ...        ...          ...              ...                    ...
# 1542         1            1                0                      0
# 1544         0            0                0                      0
# 1545         1            1                1                      0
# 1546         1            1                0                      0
# 1547         0            1                1                      0
#
#       Type_Income_State servant  Type_Income_Working  Marital_status_Married  \
# ...

# %%
#concatinating cat_dummies, Numerical, Oredinal encoded feature

X = pd.concat([X[num], X["EDUCATION"], cat_dummy], axis = 1)

# %%
X
# Out:
#       CHILDREN  Annual_income  Mobile_phone  Work_Phone  Phone  EMAIL_ID  \
# 0            0      12.100712             1           0      0         0
# 1            0      12.660328             1           1      1         0
# 4            0      12.660328             1           1      1         0
# 6            0      12.660328             1           1      1         0
# 7            0      12.100712             1           0      0         0
# ...        ...            ...           ...         ...    ...       ...
# 1542         1      12.793859             1           0      1         0
# 1544         0      12.323856             1           0      0         0
# 1545         2      12.100712             1           0      0         0
# 1546         0      12.506177             1           1      1         0
# 1547         0      12.323856             1           0      0         0
#
#       Family_Members  Age  Employement_Years  EDUCATION  ...  \
# ...

# %% [markdown]
# # SMOTE >> (Synthetic Minority Over-sampling Technique)

# %% [markdown]
# **As the dataset is imbalance, the model may become biased towords the majority classes. to unbiased it i have use SMOTE to balance the dataset.**

# %%
t_variable = y.value_counts()
plt.figure(figsize = (6,4))
plt.bar(t_variable.index, t_variable.values)
plt.xlabel("Approval Status")
plt.ylabel("Value Count")
plt.title("Target Feature's Distribution")
plt.show()

# %%
y.value_counts()
# Out:
# 0    1319
# 1     159
# Name: label, dtype: int64

# %%
smote = SMOTE(random_state=101)
x_smote, y_smote = smote.fit_resample(X, y)

# %%
y_smote.value_counts()
# Out:
# 1    1319
# 0    1319
# Name: label, dtype: int64

# %%
t_variable = y_smote.value_counts()
plt.figure(figsize = (6,4))
plt.bar(t_variable.index, t_variable.values)
plt.xlabel("Approval Status")
plt.ylabel("Value Count")
plt.title("Target Feature's Distribution")
plt.show()

# %%
x_smote.head(5)
# Out:
#    CHILDREN  Annual_income  Mobile_phone  Work_Phone  Phone  EMAIL_ID  \
# 0         0      12.100712             1           0      0         0
# 1         0      12.660328             1           1      1         0
# 2         0      12.660328             1           1      1         0
# 3         0      12.660328             1           1      1         0
# 4         0      12.100712             1           0      0         0
#
#    Family_Members  Age  Employement_Years  EDUCATION  ...  \
# 0               2   51           0.000000          1  ...
# 1               2   37           1.268858          1  ...
# 2               2   37           1.268858          1  ...
# 3               2   37           1.268858          1  ...
# 4               2   60           0.000000          3  ...
#
#    Type_Occupation_Core staff  Type_Occupation_Drivers  \
# 0                           0                        0
# 1                           0                        0
# ...

# %% [markdown]
# # **VIF method to remove the high VIF features from the dataset**

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor


#vif dataframe
vif_data = pd.DataFrame()
vif_data["Feature"] = x_smote.columns


vif_data["VIF"] = [variance_inflation_factor(x_smote.values, i)
                  for i in range(len(x_smote.columns))]
print(vif_data)
# Out:
#                                   Feature          VIF
# 0                                CHILDREN     8.810425
# 1                           Annual_income     1.306043
# 2                            Mobile_phone  1051.036712
# 3                              Work_Phone     1.271695
# 4                                   Phone     1.216942
# 5                                EMAIL_ID     1.084424
# 6                          Family_Members    12.227951
# 7                                     Age     2.261417
# 8                       Employement_Years     2.113743
# 9                               EDUCATION     1.201417
# 10                               GENDER_M     1.253419
# 11                            Car_Owner_Y     1.295620
# 12                        Propert_Owner_Y     1.182241
# 13                  Type_Income_Pensioner          inf
# 14              Type_Income_State servant    19.395749
# 15                    Type_Income_Working          inf
# ...

# %% [markdown]
# **drop the high vif & infinte value features from the dataset**

# %%
x_smote = x_smote.drop(columns = ["Mobile_phone", "CHILDREN", "Family_Members", "Type_Income_Pensioner", 
                                  "Type_Income_State servant", "Type_Income_Working", "Type_Occupation_Core staff",
                                 "Type_Occupation_Pensioner", "Type_Occupation_Working"]) 

x_smote.head()
# Out:
#    Annual_income  Work_Phone  Phone  EMAIL_ID  Age  Employement_Years  \
# 0      12.100712           0      0         0   51           0.000000
# 1      12.660328           1      1         0   37           1.268858
# 2      12.660328           1      1         0   37           1.268858
# 3      12.660328           1      1         0   37           1.268858
# 4      12.100712           0      0         0   60           0.000000
#
#    EDUCATION  GENDER_M  Car_Owner_Y  Propert_Owner_Y  ...  \
# 0          1         1            1                1  ...
# 1          1         0            1                0  ...
# 2          1         0            1                0  ...
# 3          1         0            1                0  ...
# 4          3         0            0                0  ...
#
#    Housing_type_With parents  Type_Occupation_Commercial associate  \
# 0                          0                                     0
# ...

# %%
vif_data = pd.DataFrame()
vif_data["Feature_1"] = x_smote.columns


vif_data["VIF_1"] = [variance_inflation_factor(x_smote.values, i)
                  for i in range(len(x_smote.columns))]
print(vif_data)
# Out:
#                                 Feature_1      VIF_1
# 0                           Annual_income  35.881779
# 1                              Work_Phone   1.454992
# 2                                   Phone   1.572808
# 3                                EMAIL_ID   1.142422
# 4                                     Age  21.465911
# 5                       Employement_Years   3.897892
# 6                               EDUCATION   7.232347
# 7                                GENDER_M   1.779531
# 8                             Car_Owner_Y   1.882026
# 9                         Propert_Owner_Y   2.725500
# 10                 Marital_status_Married   4.740638
# 11               Marital_status_Separated   1.268643
# 12    Marital_status_Single / not married   1.655627
# 13                   Marital_status_Widow   1.266117
# 14         Housing_type_House / apartment  12.741591
# 15       Housing_type_Municipal apartment   1.527521
# 16          Housing_type_Office apartment   1.082335
# ...

# %%
x_smote = x_smote.drop(columns = ["Age", "Housing_type_House / apartment", "EDUCATION"]) 

x_smote.head()
# Out:
#    Annual_income  Work_Phone  Phone  EMAIL_ID  Employement_Years  GENDER_M  \
# 0      12.100712           0      0         0           0.000000         1
# 1      12.660328           1      1         0           1.268858         0
# 2      12.660328           1      1         0           1.268858         0
# 3      12.660328           1      1         0           1.268858         0
# 4      12.100712           0      0         0           0.000000         0
#
#    Car_Owner_Y  Propert_Owner_Y  Marital_status_Married  \
# 0            1                1                       1
# 1            1                0                       1
# 2            1                0                       1
# 3            1                0                       1
# 4            0                0                       1
#
#    Marital_status_Separated  ...  Housing_type_With parents  \
# 0                         0  ...                          0
# ...

# %%
vif_data = pd.DataFrame()
vif_data["Feature_1"] = x_smote.columns


vif_data["VIF_1"] = [variance_inflation_factor(x_smote.values, i)
                  for i in range(len(x_smote.columns))]
print(vif_data)
# Out:
#                                 Feature_1     VIF_1
# 0                           Annual_income  9.295943
# 1                              Work_Phone  1.432309
# 2                                   Phone  1.552226
# 3                                EMAIL_ID  1.094197
# 4                       Employement_Years  3.568972
# 5                                GENDER_M  1.753561
# 6                             Car_Owner_Y  1.835229
# 7                         Propert_Owner_Y  2.504844
# 8                  Marital_status_Married  4.560040
# 9                Marital_status_Separated  1.245159
# 10    Marital_status_Single / not married  1.628045
# 11                   Marital_status_Widow  1.233583
# 12       Housing_type_Municipal apartment  1.107732
# 13          Housing_type_Office apartment  1.023833
# 14          Housing_type_Rented apartment  1.063805
# 15              Housing_type_With parents  1.070686
# 16   Type_Occupation_Commercial associate  1.321850
# ...

# %%
x_smote.columns
# Out:
# Index(['Annual_income', 'Work_Phone', 'Phone', 'EMAIL_ID', 'Employement_Years',
#        'GENDER_M', 'Car_Owner_Y', 'Propert_Owner_Y', 'Marital_status_Married',
#        'Marital_status_Separated', 'Marital_status_Single / not married',
#        'Marital_status_Widow', 'Housing_type_Municipal apartment',
#        'Housing_type_Office apartment', 'Housing_type_Rented apartment',
#        'Housing_type_With parents', 'Type_Occupation_Commercial associate',
#        'Type_Occupation_Cooking staff', 'Type_Occupation_Drivers',
#        'Type_Occupation_High skill tech staff', 'Type_Occupation_Laborers',
#        'Type_Occupation_Managers', 'Type_Occupation_Medicine staff',
#        'Type_Occupation_Private service staff', 'Type_Occupation_Secretaries'],
#       dtype='object')

# %%
final_v_features = x_smote.columns
final_v_features
# Out:
# Index(['Annual_income', 'Work_Phone', 'Phone', 'EMAIL_ID', 'Employement_Years',
#        'GENDER_M', 'Car_Owner_Y', 'Propert_Owner_Y', 'Marital_status_Married',
#        'Marital_status_Separated', 'Marital_status_Single / not married',
#        'Marital_status_Widow', 'Housing_type_Municipal apartment',
#        'Housing_type_Office apartment', 'Housing_type_Rented apartment',
#        'Housing_type_With parents', 'Type_Occupation_Commercial associate',
#        'Type_Occupation_Cooking staff', 'Type_Occupation_Drivers',
#        'Type_Occupation_High skill tech staff', 'Type_Occupation_Laborers',
#        'Type_Occupation_Managers', 'Type_Occupation_Medicine staff',
#        'Type_Occupation_Private service staff', 'Type_Occupation_Secretaries'],
#       dtype='object')

# %%
x_smote[final_v_features].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2638 entries, 0 to 2637
# Data columns (total 25 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Annual_income                          2638 non-null   float64
#  1   Work_Phone                             2638 non-null   int64
#  2   Phone                                  2638 non-null   int64
#  3   EMAIL_ID                               2638 non-null   int64
#  4   Employement_Years                      2638 non-null   float64
#  5   GENDER_M                               2638 non-null   uint8
#  6   Car_Owner_Y                            2638 non-null   uint8
#  7   Propert_Owner_Y                        2638 non-null   uint8
#  8   Marital_status_Married                 2638 non-null   uint8
#  9   Marital_status_Separated               2638 non-null   uint8
# ...

# %%
x_smote.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2638 entries, 0 to 2637
# Data columns (total 25 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Annual_income                          2638 non-null   float64
#  1   Work_Phone                             2638 non-null   int64
#  2   Phone                                  2638 non-null   int64
#  3   EMAIL_ID                               2638 non-null   int64
#  4   Employement_Years                      2638 non-null   float64
#  5   GENDER_M                               2638 non-null   uint8
#  6   Car_Owner_Y                            2638 non-null   uint8
#  7   Propert_Owner_Y                        2638 non-null   uint8
#  8   Marital_status_Married                 2638 non-null   uint8
#  9   Marital_status_Separated               2638 non-null   uint8
# ...

# %%
x_smote = x_smote.reset_index(drop=True)
x_smote
# Out:
#       Annual_income  Work_Phone  Phone  EMAIL_ID  Employement_Years  GENDER_M  \
# 0         12.100712           0      0         0           0.000000         1
# 1         12.660328           1      1         0           1.268858         0
# 2         12.660328           1      1         0           1.268858         0
# 3         12.660328           1      1         0           1.268858         0
# 4         12.100712           0      0         0           0.000000         0
# ...             ...         ...    ...       ...                ...       ...
# 2633      12.100712           0      0         0           4.682028         0
# 2634      12.014984           0      0         0           2.996665         0
# 2635      11.939806           0      0         0           1.300451         0
# 2636      11.847715           0      0         0           1.243585         0
# 2637      12.422041           0      0         0           2.384681         1
#
# ...

# %%
x_smote = x_smote[final_v_features].copy()
x_smote.head()
# Out:
#    Annual_income  Work_Phone  Phone  EMAIL_ID  Employement_Years  GENDER_M  \
# 0      12.100712           0      0         0           0.000000         1
# 1      12.660328           1      1         0           1.268858         0
# 2      12.660328           1      1         0           1.268858         0
# 3      12.660328           1      1         0           1.268858         0
# 4      12.100712           0      0         0           0.000000         0
#
#    Car_Owner_Y  Propert_Owner_Y  Marital_status_Married  \
# 0            1                1                       1
# 1            1                0                       1
# 2            1                0                       1
# 3            1                0                       1
# 4            0                0                       1
#
#    Marital_status_Separated  ...  Housing_type_With parents  \
# 0                         0  ...                          0
# ...

# %% [markdown]
# # DataSet Split into Train Test

# %%
X_train, X_test, y_train, y_test = train_test_split(x_smote, y_smote, test_size=0.2, random_state=101)

# %%
#Index resetting in the train dataset
X_train = X_train.reset_index(drop=True)
X_train
# Out:
#       Annual_income  Work_Phone  Phone  EMAIL_ID  Employement_Years  GENDER_M  \
# 0         11.630709           0      0         0           0.000000         0
# 1         11.813030           0      0         0           0.000000         0
# 2         12.218495           0      0         0           0.000000         1
# 3         12.100712           0      0         0           1.649242         0
# 4         11.630709           0      0         0           1.590597         0
# ...             ...         ...    ...       ...                ...       ...
# 2105      11.407565           0      1         0           0.000000         0
# 2106      12.306110           0      0         0           3.589011         0
# 2107      12.586220           0      0         0           5.428628         0
# 2108      12.660328           1      1         0           1.268858         0
# 2109      11.407565           1      0         0           0.509902         0
#
# ...

# %%
pip install imblearn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# **Now since the features in train and test dataset not with equal magnitude, so the higher magnitude features will get the preference from the model and it may impect our model's accuracy, so to balance it i used standard scaller.**

# %%
sc =StandardScaler()
X_train =sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train
# Out:
# array([[-0.85921054, -0.42592367, -0.54339044, ..., -0.08172753,
#         -0.03080206, -0.03080206],
#        [-0.45287052, -0.42592367, -0.54339044, ..., -0.08172753,
#         -0.03080206, -0.03080206],
#        [ 0.45078949, -0.42592367, -0.54339044, ..., -0.08172753,
#         -0.03080206, -0.03080206],
#        ...,
#        [ 1.27033763, -0.42592367, -0.54339044, ..., -0.08172753,
#         -0.03080206, -0.03080206],
#        [ 1.43550206,  2.34783851,  1.84029736, ..., -0.08172753,
#         -0.03080206, -0.03080206],
#        [-1.35653053,  2.34783851, -0.54339044, ..., -0.08172753,
#         -0.03080206, -0.03080206]])

# %%
X_test
# Out:
# array([[ 0.18828646, -0.42592367, -0.54339044, ..., -0.08172753,
#         -0.03080206, -0.03080206],
#        [ 0.18828646,  2.34783851, -0.54339044, ..., -0.08172753,
#         -0.03080206, -0.03080206],
#        [-0.04369667, -0.42592367, -0.54339044, ..., -0.08172753,
#         -0.03080206, -0.03080206],
#        ...,
#        [-0.45287052, -0.42592367, -0.54339044, ..., -0.08172753,
#         -0.03080206, -0.03080206],
#        [-0.45287052, -0.42592367, -0.54339044, ..., -0.08172753,
#         -0.03080206, -0.03080206],
#        [ 0.41355621, -0.42592367, -0.54339044, ..., -0.08172753,
#         -0.03080206, -0.03080206]])

# %% [markdown]
# # Modeling -->  Import Model Liberaries

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install joblib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.linear_model import LogisticRegression 
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC 
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
import joblib


#Hyperparameter tuning 

from sklearn.model_selection import GridSearchCV


#Evaluation metrics
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
from sklearn.metrics import confusion_matrix

# %% [markdown]
# # LogisticRegression

# %%
#modeling Logistic regression
log_reg = LogisticRegression(random_state=29, C=0.01, penalty='l2', solver='newton-cg')
log_reg.fit(X_train, y_train)

#prediction
log_train_pred = log_reg.predict(X_train)
log_test_pred = log_reg.predict(X_test)
log_cv = cross_val_score(log_reg, X, y, cv=5, scoring="accuracy").mean()

#evaluation metrics
print("Train Accuracy :", accuracy_score(y_train, log_train_pred))
print("Test Accuracy :", accuracy_score(y_test, log_test_pred))
print("Log_CV_Score :", log_cv)
print("===============================================================")
classification_report_logreg = classification_report(y_test, log_test_pred)
print(classification_report_logreg)
# Out:
# Train Accuracy : 0.7123222748815166
# Test Accuracy : 0.6931818181818182
# Log_CV_Score : 0.8924232707283555
# ...
#               precision    recall  f1-score   support
#
#            0       0.74      0.65      0.69       277
#            1       0.66      0.75      0.70       251
#
#     accuracy                           0.69       528
#    macro avg       0.70      0.70      0.69       528
# weighted avg       0.70      0.69      0.69       528

# %% [markdown]
# >Hyperparameter Tuning

# %%
log_reg = LogisticRegression(random_state=29)
param_grid = {
    'C':[0.001, 0.01, 0.1, 1, 10, 100],
    'penalty':['l1','l2'],
    'solver':['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']
}

grid_search = GridSearchCV(estimator=log_reg, param_grid=param_grid, cv=5)
grid_search.fit(X_train, y_train)
best_grid =grid_search.best_params_
print("Best Grid:",best_grid)
# Out:
# Best Grid: {'C': 0.01, 'penalty': 'l2', 'solver': 'newton-cg'}

# %% [markdown]
# # K-NearestNeighbors

# %%
knn_model = KNeighborsClassifier(n_neighbors=1)
knn_model.fit(X_train, y_train)


#prediction
knn_train_pred = knn_model.predict(X_train)
knn_test_pred = knn_model.predict(X_test)
knn_cv = cross_val_score(knn_model, X, y, cv=5, scoring="accuracy").mean()

#evaluation metrics
print("Train Accuracy :", accuracy_score(y_train, knn_train_pred))
print("Test Accuracy :", accuracy_score(y_test, knn_test_pred))
print("KNN_CV_Score :", knn_cv)
print("===============================================================")
classification_report_knn = classification_report(y_test, knn_test_pred)
print(classification_report_knn)
# Out:
# Train Accuracy : 0.9895734597156398
# Test Accuracy : 0.7954545454545454
# KNN_CV_Score : 0.847093449381585
# ...
#               precision    recall  f1-score   support
#
#            0       0.84      0.75      0.79       277
#            1       0.75      0.85      0.80       251
#
#     accuracy                           0.80       528
#    macro avg       0.80      0.80      0.80       528
# weighted avg       0.80      0.80      0.80       528

# %% [markdown]
# >Hyperparameter Tuning

# %%
knn_model = KNeighborsClassifier()
param_grid = {'n_neighbors' : list(range(1,71))}
cv_classifier = GridSearchCV(estimator=knn_model, param_grid=param_grid, cv=5, scoring="accuracy")
cv_classifier.fit(X_train, y_train)
best_param = cv_classifier.best_params_
print("Best Param: ", best_param)
# Out:
# Best Param:  {'n_neighbors': 1}

# %% [markdown]
# # SVM > Support Vector Machine

# %%
#SVM Modeling
svm_model = SVC(random_state=27, kernel='rbf')
svm_model.fit(X_train, y_train)

#prediction
svm_train_pred = svm_model.predict(X_train)
svm_test_pred = svm_model.predict(X_test)
svm_cv = cross_val_score(svm_model, X, y, cv=5, scoring="accuracy").mean()

#evaluation metrics
print("Train Accuracy :", accuracy_score(y_train, svm_train_pred))
print("Test Accuracy :", accuracy_score(y_test, svm_test_pred))
print("SVM_CV_Score :", svm_cv)
print("===============================================================")
classification_report_svm = classification_report(y_test, svm_test_pred)
print(classification_report_svm)
# Out:
# Train Accuracy : 0.7990521327014218
# Test Accuracy : 0.7310606060606061
# SVM_CV_Score : 0.8924232707283555
# ...
#               precision    recall  f1-score   support
#
#            0       0.79      0.66      0.72       277
#            1       0.68      0.80      0.74       251
#
#     accuracy                           0.73       528
#    macro avg       0.74      0.73      0.73       528
# weighted avg       0.74      0.73      0.73       528

# %% [markdown]
# >Hyperparameter Tuning

# %%
svm_model = SVC(random_state=27)
param_grid = {'kernel' : ['linear', 'poly', 'sigmoid', 'rbf']}
svm_grid = GridSearchCV(estimator=svm_model, param_grid=param_grid, cv=5, scoring="accuracy")
svm_grid.fit(X_train, y_train)
svm_grid.best_params_
# Out:
# {'kernel': 'rbf'}

# %% [markdown]
# # Decision Tree

# %%
dt_model = DecisionTreeClassifier(random_state=25, criterion="entropy", max_depth=30)
dt_model.fit(X_train, y_train)

#prediction
dt_train_pred = dt_model.predict(X_train)
dt_test_pred = dt_model.predict(X_test)
dt_cv = cross_val_score(dt_model, X, y, cv=5, scoring="accuracy").mean()

#evaluation metrics
print("Train Accuracy :", accuracy_score(y_train, dt_train_pred))
print("Test Accuracy :", accuracy_score(y_test, dt_test_pred))
print("Decision_Tree_CV_Score :", dt_cv)
print("===============================================================")
classification_report_dt = classification_report(y_test, dt_test_pred)
print(classification_report_dt)
# Out:
# Train Accuracy : 0.9933649289099526
# Test Accuracy : 0.8106060606060606
# Decision_Tree_CV_Score : 0.8254374713696748
# ...
#               precision    recall  f1-score   support
#
#            0       0.87      0.75      0.81       277
#            1       0.76      0.88      0.82       251
#
#     accuracy                           0.81       528
#    macro avg       0.82      0.81      0.81       528
# weighted avg       0.82      0.81      0.81       528

# %% [markdown]
# >Hyperparameter Tuning

# %%
dt_model = DecisionTreeClassifier(random_state=25)
param_grid = {'criterion' : ["ginni", "entropy", "log_loss"], "max_depth" : list(range(1,81))}
dt_grid = GridSearchCV(estimator=dt_model, param_grid=param_grid, cv=5)
dt_grid.fit(X_train, y_train)
dt_grid.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 30}

# %% [markdown]
# # Random Forest

# %%
#Random Forest Modeling
rf_model = RandomForestClassifier(random_state=24, 
                                  max_depth=20, 
                                  bootstrap=False, 
                                  n_estimators=100, 
                                  min_samples_leaf=1, 
                                  min_samples_split=2)
rf_model.fit(X_train, y_train)

#prediction
rf_train_pred = rf_model.predict(X_train)
rf_test_pred = rf_model.predict(X_test)
rf_cv = cross_val_score(rf_model, X, y, cv=5, scoring="accuracy").mean()

#evaluation metrics
print("Train Accuracy :", accuracy_score(y_train, rf_train_pred))
print("Test Accuracy :", accuracy_score(y_test, rf_test_pred))
print("Decision_Tree_CV_Score :", rf_cv)
print("===============================================================")
classification_report_rf = classification_report(y_test, rf_test_pred)
print(classification_report_rf)
# Out:
# Train Accuracy : 0.9914691943127962
# Test Accuracy : 0.8598484848484849
# Decision_Tree_CV_Score : 0.8843037104901512
# ...
#               precision    recall  f1-score   support
#
#            0       0.91      0.82      0.86       277
#            1       0.82      0.91      0.86       251
#
#     accuracy                           0.86       528
#    macro avg       0.86      0.86      0.86       528
# weighted avg       0.86      0.86      0.86       528

# %% [markdown]
# >Hyperparamater Tuning

# %%
rf_model = RandomForestClassifier(random_state=24)
param_grid = {'n_estimators' : [100, 200, 300, 400, 500], 
              'max_depth': [None, 10, 20, 30, 40],
              "min_samples_split": [2, 5, 10], 
              "min_samples_leaf" : [1, 2, 4], 
              "bootstrap" : [True, False]}
rf_grid_search = GridSearchCV(estimator=rf_model, param_grid=param_grid, cv=5)
rf_grid_search.fit(X_train, y_train)
print("GridSearch:", rf_grid_search.best_params_)
# Out:
# GridSearch: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}

# %% [markdown]
# # XGB >> Xtreme Gradient Boost Classifier

# %%
#XGBoost Modeling

xgb_model = XGBClassifier(random_state=23, 
                          learning_rate=0.1, 
                          n_estimators=200, 
                          subsample=1.0,
                          max_depth=20,
                          colsample_bytree=0.7)

xgb_model.fit(X_train, y_train)

#prediction
xgb_train_pred = xgb_model.predict(X_train)
xgb_test_pred = xgb_model.predict(X_test)
xgb_cv = cross_val_score(xgb_model, X, y, cv=5, scoring="accuracy").mean()

#evaluation metrics
print("Train Accuracy :", accuracy_score(y_train, xgb_train_pred))
print("Test Accuracy :", accuracy_score(y_test, xgb_test_pred))
print("Decision_Tree_CV_Score :", xgb_cv)
print("===============================================================")
classification_report_xgb = classification_report(y_test, xgb_test_pred)
print(classification_report_xgb)
# Out:
# Train Accuracy : 0.9919431279620853
# Test Accuracy : 0.8901515151515151
# Decision_Tree_CV_Score : 0.8802359138799817
# ...
#               precision    recall  f1-score   support
#
#            0       0.93      0.86      0.89       277
#            1       0.86      0.92      0.89       251
#
#     accuracy                           0.89       528
#    macro avg       0.89      0.89      0.89       528
# weighted avg       0.89      0.89      0.89       528

# %% [markdown]
# >Hyperparameter Tuning

# %%
xgb_model = XGBClassifier(random_state=23)
param_grid = {'n_estimators' : [100, 200, 300, 400], 
              'max_depth': [None, 10, 20, 30, 40],
              "learning_rate": [0.1, 0.01, 0.001], 
              "subsample" : [0.5, 0.7, 1.0], 
              "colsample_bytree" : [0.5, 0.7, 1.0]}
xgb_grid = GridSearchCV(estimator=xgb_model, param_grid=param_grid, cv=5)
xgb_grid.fit(X_train, y_train)
xgb_grid.best_params_
# Out:
# {'colsample_bytree': 0.7,
#  'learning_rate': 0.1,
#  'max_depth': 20,
#  'n_estimators': 200,
#  'subsample': 1.0}

# %% [markdown]
# # Model Selection

# %%
final_model = pd.DataFrame({"Models" : ['Logistic Regression', 'KNN', 'SVM', 'Decision Tree', 'Random Forest', 'XGBoost'], 
            "Train_Acc_Score" : [accuracy_score(y_train, log_train_pred), 
                                accuracy_score(y_train, knn_train_pred),
                                accuracy_score(y_train, svm_train_pred), 
                                accuracy_score(y_train, dt_train_pred), 
                                accuracy_score(y_train, rf_train_pred),
                                accuracy_score(y_train, xgb_train_pred)],
            "Test_Acc_score": [ accuracy_score(y_test, log_test_pred),
                               accuracy_score(y_test, knn_test_pred), 
                               accuracy_score(y_test, svm_test_pred), 
                               accuracy_score(y_test, dt_test_pred), 
                               accuracy_score(y_test, rf_test_pred), 
                               accuracy_score(y_test, xgb_test_pred)],
            "CV_Score" : [log_cv,
                          knn_cv,
                          svm_cv,
                          dt_cv,
                          rf_cv,
                          xgb_cv]})

# %%
final_model
# Out:
#                 Models  Train_Acc_Score  Test_Acc_score  CV_Score
# 0  Logistic Regression         0.712322        0.693182  0.892423
# 1                  KNN         0.989573        0.795455  0.847093
# 2                  SVM         0.799052        0.731061  0.892423
# 3        Decision Tree         0.993365        0.810606  0.825437
# 4        Random Forest         0.991469        0.859848  0.884304
# 5              XGBoost         0.991943        0.890152  0.880236

# %% [markdown]
# **The best classifier model here among all models is XGBoost Classifier it did prediction with 89% of accuracy
# and precsion 0-->93% (Application approved), 1-->86% (Application rejected).**
